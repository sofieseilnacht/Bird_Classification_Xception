# %%
# Import the necessary packages to run the code
# !pip install keras_tuner
# import keras_tuner
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tempfile
import keras
from keras.utils import to_categorical
import keras.utils as image
from keras import layers
from keras import ops
from keras import callbacks
import tensorflow as tf
from tensorflow.keras import metrics
# Out:
# Requirement already satisfied: keras_tuner in /opt/homebrew/lib/python3.11/site-packages (1.4.7)
# Requirement already satisfied: keras in /opt/homebrew/lib/python3.11/site-packages (from keras_tuner) (3.2.0)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.11/site-packages (from keras_tuner) (23.1)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from keras_tuner) (2.31.0)
# Requirement already satisfied: kt-legacy in /opt/homebrew/lib/python3.11/site-packages (from keras_tuner) (1.0.5)
# Requirement already satisfied: absl-py in /opt/homebrew/lib/python3.11/site-packages (from keras->keras_tuner) (2.1.0)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (from keras->keras_tuner) (1.26.4)
# Requirement already satisfied: rich in /opt/homebrew/lib/python3.11/site-packages (from keras->keras_tuner) (13.7.1)
# Requirement already satisfied: namex in /opt/homebrew/lib/python3.11/site-packages (from keras->keras_tuner) (0.0.7)
# Requirement already satisfied: h5py in /opt/homebrew/lib/python3.11/site-packages (from keras->keras_tuner) (3.11.0)
# Requirement already satisfied: optree in /opt/homebrew/lib/python3.11/site-packages (from keras->keras_tuner) (0.11.0)
# Requirement already satisfied: ml-dtypes in /opt/homebrew/lib/python3.11/site-packages (from keras->keras_tuner) (0.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->keras_tuner) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->keras_tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->keras_tuner) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->keras_tuner) (2023.7.22)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/homebrew/lib/python3.11/site-packages (from optree->keras->keras_tuner) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/homebrew/lib/python3.11/site-packages (from rich->keras->keras_tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/lib/python3.11/site-packages (from rich->keras->keras_tuner) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras->keras_tuner) (0.1.2)

# %%
os.listdir('CUB_200_2011')
# Out:
# ['classes.txt',
#  '.DS_Store',
#  'images',
#  'train_test_split.txt',
#  'README',
#  'attributes',
#  'bounding_boxes.txt',
#  'parts',
#  'images.txt',
#  'image_class_labels.txt']

# %% [markdown]
# ##**README for dataset description**

# %%
with open('CUB_200_2011/README', 'r') as file:
  print(file.read())
# Out:
# ===========================================
# The Caltech-UCSD Birds-200-2011 Dataset
# ===========================================
#
# For more information about the dataset, visit the project website:
#
#   http://www.vision.caltech.edu/visipedia
#
# If you use the dataset in a publication, please cite the dataset in
# the style described on the dataset website (see url above).
#
# Directory Information
# ---------------------
#
# - images/
#     The images organized in subdirectories based on species. See
#     IMAGES AND CLASS LABELS section below for more info.
# - parts/
#     15 part locations per image. See PART LOCATIONS section below
#     for more info.
# - attributes/
#     322 binary attribute labels from MTurk workers. See ATTRIBUTE LABELS
#     section below for more info.
#
#
#
# =========================
# IMAGES AND CLASS LABELS:
# =========================
# Images are contained in the directory images/, with 200 subdirectories (one for each bird species)
#
# ------- List of image files (images.txt) ------
# The list of image file names is contained in the file images.txt, with each line corresponding to one image:
#
# <image_id> <image_name>
# ------------------------------------------
#
#
# ------- Train/test split (train_test_split.txt) ------
# The suggested train/test split is contained in the file train_test_split.txt, with each line corresponding to one image:
#
# <image_id> <is_training_image>
#
# where <image_id> corresponds to the ID in images.txt, and a value of 1 or 0 for <is_training_image> denotes that the file is in the training or test set, respectively.
# ------------------------------------------------------
#
#
# ------- List of class names (classes.txt) ------
# The list of class names (bird species) is contained in the file classes.txt, with each line corresponding to one class:
#
# <class_id> <class_name>
# --------------------------------------------
#
#
# ------- Image class labels (image_class_labels.txt) ------
# The ground truth class labels (bird species labels) for each image are contained in the file image_class_labels.txt, with each line corresponding to one image:
#
# <image_id> <class_id>
#
# where <image_id> and <class_id> correspond to the IDs in images.txt and classes.txt, respectively.
# ---------------------------------------------------------
#
#
#
#
#
# =========================
# BOUNDING BOXES:
# =========================
#
# Each image contains a single bounding box label.  Bounding box labels are contained in the file bounding_boxes.txt, with each line corresponding to one image:
#
# <image_id> <x> <y> <width> <height>
#
# where <image_id> corresponds to the ID in images.txt, and <x>, <y>, <width>, and <height> are all measured in pixels
#
#
#
#
# =========================
# PART LOCATIONS:
# =========================
#
# ------- List of part names (parts/parts.txt) ------
# The list of all part names is contained in the file parts/parts.txt, with each line corresponding to one part:
#
# <part_id> <part_name>
# ------------------------------------------
#
#
# ------- Part locations (parts/part_locs.txt) ------
# The set of all ground truth part locations is contained in the file parts/part_locs.txt, with each line corresponding to the annotation of a particular part in a particular image:
#
# <image_id> <part_id> <x> <y> <visible>
#
# where <image_id> and <part_id> correspond to the IDs in images.txt and parts/parts.txt, respectively.  <x> and <y> denote the pixel location of the center of the part.  <visible> is 0 if the part is not visible in the image and 1 otherwise.
# ----------------------------------------------------------
#
#
# ------- MTurk part locations (parts/part_click_locs.txt) ------
# A set of multiple part locations for each image and part, as perceived by multiple MTurk users is contained in parts/part_click_locs.txt, with each line corresponding to the annotation of a particular part in a particular image by a different MTurk worker:
#
# <image_id> <part_id> <x> <y> <visible> <time>
#
# where <image_id>, <part_id>, <x>, <y> are in the same format as defined in parts/part_locs.txt, and <time> is the time in seconds spent by the MTurk worker.
# ----------------------------------------------------------
#
#
#
# =========================
# ATTRIBUTE LABELS:
# =========================
#
# ------- List of attribute names (attributes/attributes.txt) ------
# The list of all attribute names is contained in the file attributes/attributes.txt, with each line corresponding to one attribute:
#
# <attribute_id> <attribute_name>
# ------------------------------------------------------------------
#
#
# ------- List of certainty names (attributes/certainties.txt) ------
# The list of all certainty names (used by workers to specify their certainty of an attribute response of is contained in the file attributes/certainties.txt, with each line corresponding to one certainty:
#
# <certainty_id> <certainty_name>
# -------------------------------------------------------------------
#
#
# ------- MTurk image attribute labels (attributes/image_attribute_labels.txt) ------
# The set of attribute labels as perceived by MTurkers for each image is contained in the file attributes/image_attribute_labels.txt, with each line corresponding to one image/attribute/worker triplet:
#
# <image_id> <attribute_id> <is_present> <certainty_id> <time>
#
# where <image_id>, <attribute_id>, <certainty_id> correspond to the IDs in images.txt, attributes/attributes.txt, and attributes/certainties.txt respectively.  <is_present> is 0 or 1 (1 denotes that the attribute is present).  <time> denotes the time spent by the MTurker in seconds.
# -----------------------------------------------------------------------------------
#
#
# ------- Class attribute labels (attributes/class_attribute_labels_continuous.txt) ------
# Attributes on a per-class level--in a similar format to the Animals With Attributes dataset--are contained in attributes/class_attribute_labels_continuous.txt.  The file contains 200 lines and 312 space-separated columns.  Each line corresponds to one class (in the same order as classes.txt) and each column contains one real-valued number corresponding to one attribute (in the same order as attributes.txt).  The number is the percentage of the time (between 0 and 100) that a human thinks that the attribute is present for a given class
# ----------------------------------------------------------------------------------------

# %% [markdown]
# ##**Importing data and cleaning**

# %%
#Images and class labels

images = pd.read_csv("CUB_200_2011/images.txt",sep = None,names=['image_id' ,'image_name'],engine='python')
print(images)

train_test_split =pd.read_csv("CUB_200_2011/train_test_split.txt",sep = None,names=['image_id' ,'is_training_image'],engine='python')
print(train_test_split)

classes =pd.read_csv("CUB_200_2011/classes.txt",sep = None,names=['class_id', 'class_name'],engine='python')
print(classes)

image_class_labels =pd.read_csv("CUB_200_2011/image_class_labels.txt",sep = None,names=['image_id', 'class_id'],engine='python')
print(image_class_labels)
# Out:
#        image_id                                         image_name
# 0             1  001.Black_footed_Albatross/Black_Footed_Albatr...
# 1             2  001.Black_footed_Albatross/Black_Footed_Albatr...
# 2             3  001.Black_footed_Albatross/Black_Footed_Albatr...
# 3             4  001.Black_footed_Albatross/Black_Footed_Albatr...
# 4             5  001.Black_footed_Albatross/Black_Footed_Albatr...
# ...         ...                                                ...
# 11783     11784  200.Common_Yellowthroat/Common_Yellowthroat_00...
# 11784     11785  200.Common_Yellowthroat/Common_Yellowthroat_00...
# 11785     11786  200.Common_Yellowthroat/Common_Yellowthroat_00...
# 11786     11787  200.Common_Yellowthroat/Common_Yellowthroat_00...
# 11787     11788  200.Common_Yellowthroat/Common_Yellowthroat_00...
#
# [11788 rows x 2 columns]
#        image_id  is_training_image
# 0             1                  0
# 1             2                  1
# 2             3                  0
# 3             4                  1
# 4             5                  1
# ...         ...                ...
# 11783     11784                  1
# 11784     11785                  0
# 11785     11786                  0
# 11786     11787                  1
# 11787     11788                  0
#
# [11788 rows x 2 columns]
#      class_id                  class_name
# 0           1  001.Black_footed_Albatross
# 1           2        002.Laysan_Albatross
# 2           3         003.Sooty_Albatross
# 3           4       004.Groove_billed_Ani
# 4           5          005.Crested_Auklet
# ..        ...                         ...
# 195       196              196.House_Wren
# 196       197              197.Marsh_Wren
# 197       198               198.Rock_Wren
# 198       199             199.Winter_Wren
# 199       200     200.Common_Yellowthroat
#
# [200 rows x 2 columns]
#        image_id  class_id
# 0             1         1
# 1             2         1
# 2             3         1
# 3             4         1
# 4             5         1
# ...         ...       ...
# 11783     11784       200
# 11784     11785       200
# 11785     11786       200
# 11786     11787       200
# 11787     11788       200
#
# [11788 rows x 2 columns]

# %%
#bounding boxes

bounding_boxes = pd.read_csv("CUB_200_2011/bounding_boxes.txt",sep = None,names=['image_id','x','y','width','height'],engine='python')
print(bounding_boxes)
# Out:
#        image_id      x      y  width  height
# 0             1   60.0   27.0  325.0   304.0
# 1             2  139.0   30.0  153.0   264.0
# 2             3   14.0  112.0  388.0   186.0
# 3             4  112.0   90.0  255.0   242.0
# 4             5   70.0   50.0  134.0   303.0
# ...         ...    ...    ...    ...     ...
# 11783     11784   89.0   95.0  354.0   250.0
# 11784     11785  157.0   62.0  184.0   219.0
# 11785     11786  190.0  102.0  198.0   202.0
# 11786     11787    3.0   20.0  408.0   307.0
# 11787     11788   20.0  113.0  177.0   263.0
#
# [11788 rows x 5 columns]

# %%
#part locations

parts = pd.read_fwf("CUB_200_2011/parts/parts.txt",widths = [2,11],names=['part_id','part_name'],engine='python')
print(parts)

part_locs = pd.read_csv("CUB_200_2011/parts/part_locs.txt",sep = None,names=['image_id','part_id','x','y','visible'],engine='python')
print(part_locs)

part_click_locs = pd.read_csv("CUB_200_2011/parts/part_click_locs.txt",sep = None,names=['image_id','part_id','x','y','visible','time'],engine='python')
print(part_click_locs)
# Out:
#     part_id   part_name
# 0         1        back
# 1         2        beak
# 2         3       belly
# 3         4      breast
# 4         5       crown
# 5         6    forehead
# 6         7    left eye
# 7         8    left leg
# 8         9   left wing
# 9        10        nape
# 10       11   right eye
# 11       12   right leg
# 12       13  right wing
# 13       14        tail
# 14       15      throat
#         image_id  part_id      x      y  visible
# 0              1        1    0.0    0.0        0
# 1              1        2  312.0  182.0        1
# 2              1        3    0.0    0.0        0
# 3              1        4    0.0    0.0        0
# 4              1        5  186.0   45.0        1
# ...          ...      ...    ...    ...      ...
# 176815     11788       11  136.0  133.0        1
# 176816     11788       12  102.0  316.0        1
# 176817     11788       13   94.0  224.0        1
# 176818     11788       14   36.0  329.0        1
# 176819     11788       15  166.0  161.0        1
#
# [176820 rows x 5 columns]
#         image_id  part_id      x      y  visible   time
# 0              1        1    0.0    0.0        0  2.329
# 1              1        1    0.0    0.0        0  2.294
# 2              1        1    0.0    0.0        0  2.359
# 3              1        1    0.0    0.0        0  5.813
# 4              1        1    0.0    0.0        0  6.303
# ...          ...      ...    ...    ...      ...    ...
# 794253     11788       15  167.0  161.0        1  2.644
# 794254     11788       15  168.0  155.0        1  1.713
# 794255     11788       15  157.0  164.0        1  1.744
# 794256     11788       15  166.0  154.0        1  0.856
# 794257     11788       15  162.0  167.0        1  1.750
#
# [794258 rows x 6 columns]

# %%
#Attribute labels

attributes = pd.read_csv("attributes.txt",sep = None,names=['attribute_id','attribute_name'],engine='python')
print(attributes)

certainties = pd.read_fwf("CUB_200_2011/attributes/certainties.txt",widths = [2,15],names=['certainty_id','certainty_name'],engine='python')
print(certainties)

image_attribute_labels = pd.read_csv("CUB_200_2011/attributes/image_attribute_labels.txt",sep = '\s+', names=['image_id','attribute_id','is_present','certainty_id','time','temp'],engine='python')
print(image_attribute_labels)

class_attribute_labels_continuous = pd.read_csv("CUB_200_2011/attributes/class_attribute_labels_continuous.txt", sep = None, names =range(1,313), engine='python')
print(class_attribute_labels_continuous)
# Out:
#      attribute_id                       attribute_name
# 0               1  has_bill_shape::curved_(up_or_down)
# 1               2               has_bill_shape::dagger
# 2               3               has_bill_shape::hooked
# 3               4               has_bill_shape::needle
# 4               5       has_bill_shape::hooked_seabird
# ..            ...                                  ...
# 307           308                has_crown_color::buff
# 308           309              has_wing_pattern::solid
# 309           310            has_wing_pattern::spotted
# 310           311            has_wing_pattern::striped
# 311           312      has_wing_pattern::multi-colored
#
# [312 rows x 2 columns]
#    certainty_id certainty_name
# 0             1    not visible
# 1             2       guessing
# 2             3       probably
# 3             4     definitely
#          image_id  attribute_id  is_present  certainty_id    time  temp
# 0               1             1           0             3  27.708   NaN
# 1               1             2           0             3  27.708   NaN
# 2               1             3           0             3  27.708   NaN
# 3               1             4           0             3  27.708   NaN
# 4               1             5           1             3  27.708   NaN
# ...           ...           ...         ...           ...     ...   ...
# 3677851     11788           308           1             4   4.989   NaN
# 3677852     11788           309           0             4   8.309   NaN
# 3677853     11788           310           0             4   8.309   NaN
# 3677854     11788           311           0             4   8.309   NaN
# 3677855     11788           312           1             4   8.309   NaN
#
# [3677856 rows x 6 columns]
#            1          2          3         4          5          6    \
# 0     0.000000   2.919708   1.459854  0.000000  59.854015  26.277372
# 1     4.411765   4.411765   2.941176  1.470588  57.352941  27.205882
# 2     0.000000   3.973510   3.311258  0.000000  70.860927  14.569536
# 3     0.000000   1.459854  10.218978  0.000000   0.000000   0.000000
# 4     0.000000   0.000000   3.225806  0.000000   1.075269   0.000000
# ..         ...        ...        ...       ...        ...        ...
# 195   2.702703  12.837838   0.000000  0.000000   0.000000   0.000000
# 196  18.300654  11.764706   0.000000  3.267974   0.000000   0.000000
# 197  10.759494  36.708861   0.000000  7.594937   0.632911   0.000000
# 198   0.000000   2.068966   0.000000  2.068966   0.000000   0.000000
# 199   0.000000   8.280255   0.000000  0.000000   0.000000   0.000000
#
#            7          8          9         10   ...       303       304  \
# 0     3.649635   5.839416   0.000000  1.639344  ...  0.000000  0.000000
# 1     0.000000   2.205882   0.000000  0.000000  ...  0.000000  2.255639
# 2     5.298013   1.986755   0.000000  0.000000  ...  2.205882  0.000000
# 3     8.759124  25.547445  54.014599  5.839416  ...  0.000000  0.000000
# 4     0.000000  32.258065  63.440860  0.000000  ...  0.000000  0.000000
# ..         ...        ...        ...       ...  ...       ...       ...
# 195  76.351351   8.108108   0.000000  0.000000  ...  0.000000  0.000000
# 196  60.784314   5.882353   0.000000  0.000000  ...  0.000000  0.000000
# 197  43.670886   0.632911   0.000000  0.000000  ...  0.000000  0.000000
# 198  88.275862   7.586207   0.000000  0.000000  ...  0.000000  1.324503
# 199  82.802548   8.917197   0.000000  0.000000  ...  0.000000  0.000000
#
#            305        306      307        308        309        310  \
# 0    21.276596  11.347518  2.12766  31.914894  53.571429   5.357143
# 1     2.255639  94.736842  0.00000   0.000000  77.142857   3.809524
# 2    38.970588   2.941176  0.00000  16.176471  71.028037   0.934579
# 3    88.571429   0.000000  0.00000   2.142857  84.126984   2.380952
# 4    82.727273   5.454545  0.00000   4.545455  88.461538   0.000000
# ..         ...        ...      ...        ...        ...        ...
# 195   0.000000   1.973684  0.00000  29.605263  14.379085  22.875817
# 196  35.443038   4.430380  0.00000  22.784810  16.783217  25.174825
# 197  14.375000  13.125000  0.00000  41.875000  18.791946  44.295302
# 198   3.973510   0.000000  0.00000  19.205298  12.413793  34.482759
# 199  10.429448  34.969325  0.00000  38.036810  56.488550   3.053435
#
#            311        312
# 0    21.428571  19.642857
# 1    10.476190   8.571429
# 2     7.476636  20.560748
# 3     3.174603  10.317460
# 4     3.846154   7.692308
# ..         ...        ...
# 195  56.209150   6.535948
# 196  32.167832  25.874126
# 197  18.791946  18.120805
# 198  33.103448  20.000000
# 199  10.687023  29.770992
#
# [200 rows x 312 columns]

# %%
#CLEANING IMAGE ATTRIBUTE LABELS - has extra column for 606 rows
to_fix = image_attribute_labels.loc[image_attribute_labels['temp'].notnull()]
print(to_fix)
for row in to_fix.index:
  image_attribute_labels.iat[row,to_fix.columns.get_loc('time')]= image_attribute_labels['temp'][row]
to_fix = image_attribute_labels.loc[image_attribute_labels['temp'].notnull()]
print(to_fix)
image_attribute_labels.drop('temp',axis=1,inplace = True)
print(image_attribute_labels)
# Out:
#          image_id  attribute_id  is_present  certainty_id  time    temp
# 709497       2275            10           0             1   0.0   1.509
# 709498       2275            11           0             1   0.0   1.509
# 709499       2275            12           0             1   0.0   1.509
# 709500       2275            13           0             1   0.0   1.509
# 709501       2275            14           0             1   0.0   1.509
# ...           ...           ...         ...           ...   ...     ...
# 2921563      9364           308           0             3   0.0  13.288
# 2921564      9364           309           0             3   0.0   6.240
# 2921565      9364           310           0             3   0.0   6.240
# 2921566      9364           311           0             3   0.0   6.240
# 2921567      9364           312           1             3   0.0   6.240
#
# [606 rows x 6 columns]
#          image_id  attribute_id  is_present  certainty_id    time    temp
# 709497       2275            10           0             1   1.509   1.509
# 709498       2275            11           0             1   1.509   1.509
# 709499       2275            12           0             1   1.509   1.509
# 709500       2275            13           0             1   1.509   1.509
# 709501       2275            14           0             1   1.509   1.509
# ...           ...           ...         ...           ...     ...     ...
# 2921563      9364           308           0             3  13.288  13.288
# 2921564      9364           309           0             3   6.240   6.240
# 2921565      9364           310           0             3   6.240   6.240
# 2921566      9364           311           0             3   6.240   6.240
# 2921567      9364           312           1             3   6.240   6.240
#
# [606 rows x 6 columns]
#          image_id  attribute_id  is_present  certainty_id    time
# 0               1             1           0             3  27.708
# 1               1             2           0             3  27.708
# 2               1             3           0             3  27.708
# 3               1             4           0             3  27.708
# 4               1             5           1             3  27.708
# ...           ...           ...         ...           ...     ...
# 3677851     11788           308           1             4   4.989
# 3677852     11788           309           0             4   8.309
# 3677853     11788           310           0             4   8.309
# 3677854     11788           311           0             4   8.309
# 3677855     11788           312           1             4   8.309
#
# [3677856 rows x 5 columns]

# %% [markdown]
# ##**Preprocessing**

# %%
print(len(images))
print(len(train_test_split))
print(len(image_class_labels))
print(len(classes))
print(len(bounding_boxes))
# Out:
# 11788
# 11788
# 11788
# 200
# 11788

# %%
image_data = pd.merge(images,train_test_split, on='image_id')
image_data = pd.merge(image_data,image_class_labels, on='image_id')
image_data = pd.merge(image_data,classes, on='class_id')
image_data = pd.merge(image_data,bounding_boxes, on='image_id')
print(image_data.to_string())
print(len(image_data))
# Out:
#        image_id                                                                         image_name  is_training_image  class_id                          class_name      x      y  width  height
# 0             1                      001.Black_footed_Albatross/Black_Footed_Albatross_0046_18.jpg                  0         1          001.Black_footed_Albatross   60.0   27.0  325.0   304.0
# 1             2                      001.Black_footed_Albatross/Black_Footed_Albatross_0009_34.jpg                  1         1          001.Black_footed_Albatross  139.0   30.0  153.0   264.0
# 2             3                      001.Black_footed_Albatross/Black_Footed_Albatross_0002_55.jpg                  0         1          001.Black_footed_Albatross   14.0  112.0  388.0   186.0
# 3             4                      001.Black_footed_Albatross/Black_Footed_Albatross_0074_59.jpg                  1         1          001.Black_footed_Albatross  112.0   90.0  255.0   242.0
# 4             5                      001.Black_footed_Albatross/Black_Footed_Albatross_0014_89.jpg                  1         1          001.Black_footed_Albatross   70.0   50.0  134.0   303.0
# 5             6                      001.Black_footed_Albatross/Black_Footed_Albatross_0085_92.jpg                  0         1          001.Black_footed_Albatross   33.0   53.0  251.0   395.0
# 6             7                     001.Black_footed_Albatross/Black_Footed_Albatross_0031_100.jpg                  1         1          001.Black_footed_Albatross    7.0   75.0  420.0   262.0
# 7             8                  001.Black_footed_Albatross/Black_Footed_Albatross_0051_796103.jpg                  1         1          001.Black_footed_Albatross   78.0   86.0  333.0   158.0
# 8             9                  001.Black_footed_Albatross/Black_Footed_Albatross_0010_796097.jpg                  1         1          001.Black_footed_Albatross  112.0   76.0  221.0   189.0
# 9            10                  001.Black_footed_Albatross/Black_Footed_Albatross_0025_796057.jpg                  0         1          001.Black_footed_Albatross   27.0    4.0  199.0   201.0
# 10           11                  001.Black_footed_Albatross/Black_Footed_Albatross_0023_796059.jpg                  1         1          001.Black_footed_Albatross    1.0   52.0  342.0   260.0
# 11           12                  001.Black_footed_Albatross/Black_Footed_Albatross_0086_796062.jpg                  0         1          001.Black_footed_Albatross   47.0   21.0  179.0   249.0
# 12           13                  001.Black_footed_Albatross/Black_Footed_Albatross_0049_796063.jpg                  0         1          001.Black_footed_Albatross   36.0   32.0  197.0   457.0
# 13           14                  001.Black_footed_Albatross/Black_Footed_Albatross_0006_796065.jpg                  0         1          001.Black_footed_Albatross   37.0   40.0  262.0   184.0
# 14           15                  001.Black_footed_Albatross/Black_Footed_Albatross_0040_796066.jpg                  1         1          001.Black_footed_Albatross   23.0   80.0  395.0   237.0
# 15           16                  001.Black_footed_Albatross/Black_Footed_Albatross_0016_796067.jpg                  0         1          001.Black_footed_Albatross  141.0   87.0  256.0   211.0
# 16           17                  001.Black_footed_Albatross/Black_Footed_Albatross_0065_796068.jpg                  0         1          001.Black_footed_Albatross   40.0   38.0  254.0   209.0
# 17           18                  001.Black_footed_Albatross/Black_Footed_Albatross_0089_796069.jpg                  1         1          001.Black_footed_Albatross   45.0   58.0  254.0   249.0
# 18           19                  001.Black_footed_Albatross/Black_Footed_Albatross_0042_796071.jpg                  0         1          001.Black_footed_Albatross  135.0   83.0  304.0   181.0
# 19           20                     001.Black_footed_Albatross/Black_Footed_Albatross_0067_170.jpg                  1         1          001.Black_footed_Albatross   23.0  195.0  255.0   122.0
# 20           21                  001.Black_footed_Albatross/Black_Footed_Albatross_0060_796076.jpg                  1         1          001.Black_footed_Albatross   11.0   77.0  281.0   139.0
# 21           22                  001.Black_footed_Albatross/Black_Footed_Albatross_0090_796077.jpg                  0         1          001.Black_footed_Albatross    5.0    4.0  210.0   130.0
# 22           23                  001.Black_footed_Albatross/Black_Footed_Albatross_0056_796078.jpg                  1         1          001.Black_footed_Albatross  154.0   93.0  188.0   165.0
# 23           24                  001.Black_footed_Albatross/Black_Footed_Albatross_0061_796082.jpg                  0         1          001.Black_footed_Albatross   50.0   25.0  156.0   139.0
# 24           25                  001.Black_footed_Albatross/Black_Footed_Albatross_0008_796083.jpg                  0         1          001.Black_footed_Albatross  172.0  106.0  265.0   214.0
# 25           26                  001.Black_footed_Albatross/Black_Footed_Albatross_0033_796086.jpg                  0         1          001.Black_footed_Albatross   37.0   61.0  409.0   180.0
# 26           27                  001.Black_footed_Albatross/Black_Footed_Albatross_0024_796089.jpg                  0         1          001.Black_footed_Albatross   65.0   62.0  309.0   345.0
# 27           28                  001.Black_footed_Albatross/Black_Footed_Albatross_0005_796090.jpg                  0         1          001.Black_footed_Albatross    1.0    2.0  499.0   286.0
# 28           29                  001.Black_footed_Albatross/Black_Footed_Albatross_0026_796095.jpg                  0         1          001.Black_footed_Albatross   97.0    3.0  235.0   254.0
# 29           30                  001.Black_footed_Albatross/Black_Footed_Albatross_0080_796096.jpg                  1         1          001.Black_footed_Albatross   90.0   29.0  224.0   211.0
# 30           31                  001.Black_footed_Albatross/Black_Footed_Albatross_0047_796064.jpg                  1         1          001.Black_footed_Albatross   38.0   15.0  314.0   301.0
# 31           32                  001.Black_footed_Albatross/Black_Footed_Albatross_0017_796098.jpg                  1         1          001.Black_footed_Albatross   20.0   91.0  416.0   203.0
# 32           33                  001.Black_footed_Albatross/Black_Footed_Albatross_0064_796101.jpg                  0         1          001.Black_footed_Albatross   82.0   52.0  260.0   260.0
# 33           34                     001.Black_footed_Albatross/Black_Footed_Albatross_0076_417.jpg                  0         1          001.Black_footed_Albatross   66.0  115.0  360.0   214.0
# 34           35                  001.Black_footed_Albatross/Black_Footed_Albatross_0019_796104.jpg                  1         1          001.Black_footed_Albatross   19.0   18.0  464.0   294.0
# 35           36                  001.Black_footed_Albatross/Black_Footed_Albatross_0057_796106.jpg                  1         1          001.Black_footed_Albatross   72.0   40.0  286.0   225.0
# 36           37                  001.Black_footed_Albatross/Black_Footed_Albatross_0041_796108.jpg                  1         1          001.Black_footed_Albatross  216.0  119.0  221.0   154.0
# 37           38                  001.Black_footed_Albatross/Black_Footed_Albatross_0053_796109.jpg                  0         1          001.Black_footed_Albatross   40.0    4.0  368.0   445.0
# 38           39                  001.Black_footed_Albatross/Black_Footed_Albatross_0001_796111.jpg                  0         1          001.Black_footed_Albatross   69.0   57.0  199.0   141.0
# 39           40                  001.Black_footed_Albatross/Black_Footed_Albatross_0071_796113.jpg                  1         1          001.Black_footed_Albatross  130.0   29.0  202.0   393.0
# 40           41                  001.Black_footed_Albatross/Black_Footed_Albatross_0077_796114.jpg                  1         1          001.Black_footed_Albatross   53.0   46.0  302.0   317.0
# 41           42                  001.Black_footed_Albatross/Black_Footed_Albatross_0032_796115.jpg                  1         1          001.Black_footed_Albatross   25.0   17.0  368.0   299.0
# 42           43                     001.Black_footed_Albatross/Black_Footed_Albatross_0038_212.jpg                  1         1          001.Black_footed_Albatross  137.0   64.0  287.0   156.0
# 43           44                  001.Black_footed_Albatross/Black_Footed_Albatross_0037_796120.jpg                  0         1          001.Black_footed_Albatross  111.0   42.0  133.0   219.0
# 44           45                  001.Black_footed_Albatross/Black_Footed_Albatross_0082_796121.jpg                  0         1          001.Black_footed_Albatross   58.0   51.0  388.0   211.0
# 45           46                  001.Black_footed_Albatross/Black_Footed_Albatross_0079_796122.jpg                  1         1          001.Black_footed_Albatross   13.0   28.0  212.0   283.0
# 46           47                  001.Black_footed_Albatross/Black_Footed_Albatross_0050_796125.jpg                  0         1          001.Black_footed_Albatross    5.0  127.0  496.0   131.0
# 47           48                  001.Black_footed_Albatross/Black_Footed_Albatross_0078_796126.jpg                  0         1          001.Black_footed_Albatross  113.0  260.0  127.0   130.0
# 48           49                  001.Black_footed_Albatross/Black_Footed_Albatross_0036_796127.jpg                  1         1          001.Black_footed_Albatross   49.0   69.0  253.0   211.0
# 49           50                  001.Black_footed_Albatross/Black_Footed_Albatross_0045_796129.jpg                  0         1          001.Black_footed_Albatross   24.0  144.0  433.0   130.0
# 50           51                  001.Black_footed_Albatross/Black_Footed_Albatross_0039_796132.jpg                  1         1          001.Black_footed_Albatross  151.0  152.0  310.0   200.0
# 51           52                  001.Black_footed_Albatross/Black_Footed_Albatross_0088_796133.jpg                  0         1          001.Black_footed_Albatross  157.0   45.0  103.0   324.0
# 52           53                  001.Black_footed_Albatross/Black_Footed_Albatross_0068_796135.jpg                  1         1          001.Black_footed_Albatross   60.0   29.0  432.0   355.0
# 53           54                  001.Black_footed_Albatross/Black_Footed_Albatross_0003_796136.jpg                  0         1          001.Black_footed_Albatross  131.0   36.0  212.0   304.0
# 54           55                  001.Black_footed_Albatross/Black_Footed_Albatross_0007_796138.jpg                  1         1          001.Black_footed_Albatross  152.0   86.0  120.0   141.0
# 55           56                  001.Black_footed_Albatross/Black_Footed_Albatross_0069_796139.jpg                  1         1          001.Black_footed_Albatross    2.0   45.0  189.0   120.0
# 56           57                  001.Black_footed_Albatross/Black_Footed_Albatross_0035_796140.jpg                  0         1          001.Black_footed_Albatross  214.0   87.0  204.0   179.0
# 57           58                  001.Black_footed_Albatross/Black_Footed_Albatross_0063_796141.jpg                  1         1          001.Black_footed_Albatross   46.0   24.0  197.0   117.0
# 58           59                  001.Black_footed_Albatross/Black_Footed_Albatross_0058_796074.jpg                  0         1          001.Black_footed_Albatross   72.0   29.0  224.0   262.0
# 59           60                     001.Black_footed_Albatross/Black_Footed_Albatross_0081_426.jpg                  1         1          001.Black_footed_Albatross   96.0   77.0  260.0   170.0
# 60           61                                002.Laysan_Albatross/Laysan_Albatross_0002_1027.jpg                  0         2                002.Laysan_Albatross  144.0   40.0  333.0   165.0
# 61           62                                002.Laysan_Albatross/Laysan_Albatross_0003_1033.jpg                  1         2                002.Laysan_Albatross  202.0   28.0  164.0   340.0
# 62           63                                 002.Laysan_Albatross/Laysan_Albatross_0082_524.jpg                  0         2                002.Laysan_Albatross   72.0   68.0  383.0   225.0
# 63           64                                 002.Laysan_Albatross/Laysan_Albatross_0044_784.jpg                  1         2                002.Laysan_Albatross   60.0  128.0  438.0   106.0
# 64           65                                 002.Laysan_Albatross/Laysan_Albatross_0070_788.jpg                  0         2                002.Laysan_Albatross   32.0   35.0  259.0   361.0
# 65           66                                 002.Laysan_Albatross/Laysan_Albatross_0050_870.jpg                  1         2                002.Laysan_Albatross   41.0   79.0  387.0   202.0
# 66           67                                 002.Laysan_Albatross/Laysan_Albatross_0071_792.jpg                  1         2                002.Laysan_Albatross  156.0   35.0  126.0   259.0
# 67           68                                 002.Laysan_Albatross/Laysan_Albatross_0053_543.jpg                  0         2                002.Laysan_Albatross  108.0  123.0  230.0   149.0
# 68           69                                 002.Laysan_Albatross/Laysan_Albatross_0081_800.jpg                  1         2                002.Laysan_Albatross   82.0   75.0  308.0   260.0
# 69           70                                 002.Laysan_Albatross/Laysan_Albatross_0001_545.jpg                  0         2                002.Laysan_Albatross   89.0  172.0  108.0   146.0
# 70           71                                002.Laysan_Albatross/Laysan_Albatross_0023_1059.jpg                  0         2                002.Laysan_Albatross   83.0  124.0  211.0   250.0
# 71           72                                 002.Laysan_Albatross/Laysan_Albatross_0065_809.jpg                  1         2                002.Laysan_Albatross   75.0   80.0  375.0   277.0
# 72           73                                 002.Laysan_Albatross/Laysan_Albatross_0061_563.jpg                  1         2                002.Laysan_Albatross   41.0   31.0  384.0   260.0
# 73           74                                 002.Laysan_Albatross/Laysan_Albatross_0085_564.jpg                  1         2                002.Laysan_Albatross   45.0   31.0  268.0   306.0
# 74           75                                 002.Laysan_Albatross/Laysan_Albatross_0005_565.jpg                  1         2                002.Laysan_Albatross   38.0   91.0  316.0   193.0
# 75           76                                 002.Laysan_Albatross/Laysan_Albatross_0060_777.jpg                  0         2                002.Laysan_Albatross  137.0   72.0  202.0   211.0
# 76           77                                 002.Laysan_Albatross/Laysan_Albatross_0055_570.jpg                  1         2                002.Laysan_Albatross   15.0   25.0  409.0   274.0
# 77           78                                 002.Laysan_Albatross/Laysan_Albatross_0025_571.jpg                  1         2                002.Laysan_Albatross  193.0   46.0  202.0   195.0
# 78           79                                 002.Laysan_Albatross/Laysan_Albatross_0080_821.jpg                  0         2                002.Laysan_Albatross   99.0  115.0  316.0   284.0
# 79           80                                 002.Laysan_Albatross/Laysan_Albatross_0092_834.jpg                  1         2                002.Laysan_Albatross   71.0   50.0  312.0   236.0
# 80           81                                 002.Laysan_Albatross/Laysan_Albatross_0013_910.jpg                  1         2                002.Laysan_Albatross   67.0   25.0  358.0   248.0
# 81           82                                 002.Laysan_Albatross/Laysan_Albatross_0091_602.jpg                  0         2                002.Laysan_Albatross  109.0   13.0  276.0   295.0
# 82           83                                 002.Laysan_Albatross/Laysan_Albatross_0102_611.jpg                  0         2                002.Laysan_Albatross   35.0  114.0  418.0   216.0
# 83           84                                 002.Laysan_Albatross/Laysan_Albatross_0099_869.jpg                  1         2                002.Laysan_Albatross   41.0   89.0  378.0   304.0
# 84           85                                 002.Laysan_Albatross/Laysan_Albatross_0017_614.jpg                  0         2                002.Laysan_Albatross    8.0   75.0  350.0   424.0
# 85           86                                 002.Laysan_Albatross/Laysan_Albatross_0047_619.jpg                  1         2                002.Laysan_Albatross  157.0   36.0  195.0   365.0
# 86           87                                 002.Laysan_Albatross/Laysan_Albatross_0035_876.jpg                  0         2                002.Laysan_Albatross   30.0    7.0  437.0   321.0
# 87           88                                 002.Laysan_Albatross/Laysan_Albatross_0098_621.jpg                  0         2                002.Laysan_Albatross   58.0   91.0  332.0   256.0
# 88           89                                 002.Laysan_Albatross/Laysan_Albatross_0088_883.jpg                  1         2                002.Laysan_Albatross   84.0   25.0  285.0   307.0
# 89           90                                 002.Laysan_Albatross/Laysan_Albatross_0034_628.jpg                  0         2                002.Laysan_Albatross  193.0   53.0  244.0   254.0
# 90           91                                 002.Laysan_Albatross/Laysan_Albatross_0104_630.jpg                  0         2                002.Laysan_Albatross  119.0   42.0  118.0   123.0
# 91           92                                 002.Laysan_Albatross/Laysan_Albatross_0058_637.jpg                  0         2                002.Laysan_Albatross   18.0   60.0  459.0   239.0
# 92           93                                 002.Laysan_Albatross/Laysan_Albatross_0028_643.jpg                  0         2                002.Laysan_Albatross  135.0  120.0  201.0   138.0
# 93           94                                 002.Laysan_Albatross/Laysan_Albatross_0033_658.jpg                  0         2                002.Laysan_Albatross   45.0   10.0  322.0   281.0
# 94           95                                 002.Laysan_Albatross/Laysan_Albatross_0075_668.jpg                  0         2                002.Laysan_Albatross  120.0   60.0  101.0   218.0
# 95           96                                 002.Laysan_Albatross/Laysan_Albatross_0076_671.jpg                  1         2                002.Laysan_Albatross  151.0   23.0  274.0   351.0
# 96           97                                 002.Laysan_Albatross/Laysan_Albatross_0096_673.jpg                  1         2                002.Laysan_Albatross   46.0   71.0  403.0   280.0
# 97           98                                 002.Laysan_Albatross/Laysan_Albatross_0064_674.jpg                  0         2                002.Laysan_Albatross  118.0   19.0  222.0   294.0
# 98           99                                 002.Laysan_Albatross/Laysan_Albatross_0039_924.jpg                  1         2                002.Laysan_Albatross   24.0   53.0  361.0   181.0
# 99          100                                 002.Laysan_Albatross/Laysan_Albatross_0049_918.jpg                  0         2                002.Laysan_Albatross   13.0   58.0  473.0   243.0
# 100         101                                 002.Laysan_Albatross/Laysan_Albatross_0012_696.jpg                  0         2                002.Laysan_Albatross  125.0   72.0  306.0   149.0
# 101         102                                 002.Laysan_Albatross/Laysan_Albatross_0056_500.jpg                  1         2                002.Laysan_Albatross   92.0   47.0  331.0   260.0
# 102         103                                 002.Laysan_Albatross/Laysan_Albatross_0037_699.jpg                  0         2                002.Laysan_Albatross  152.0   41.0  187.0   271.0
# 103         104                                 002.Laysan_Albatross/Laysan_Albatross_0006_702.jpg                  1         2                002.Laysan_Albatross   83.0   90.0  245.0   394.0
# 104         105                                 002.Laysan_Albatross/Laysan_Albatross_0073_927.jpg                  1         2                002.Laysan_Albatross  127.0   55.0  252.0   182.0
# 105         106                                 002.Laysan_Albatross/Laysan_Albatross_0042_801.jpg                  0         2                002.Laysan_Albatross  116.0   18.0  283.0   314.0
# 106         107                                 002.Laysan_Albatross/Laysan_Albatross_0004_930.jpg                  0         2                002.Laysan_Albatross   64.0   94.0  287.0   223.0
# 107         108                                 002.Laysan_Albatross/Laysan_Albatross_0093_725.jpg                  0         2                002.Laysan_Albatross  138.0   88.0  120.0   156.0
# 108         109                                 002.Laysan_Albatross/Laysan_Albatross_0068_726.jpg                  1         2                002.Laysan_Albatross   43.0   62.0  286.0   432.0
# 109         110                                 002.Laysan_Albatross/Laysan_Albatross_0040_472.jpg                  1         2                002.Laysan_Albatross  148.0  115.0  149.0   193.0
# 110         111                                 002.Laysan_Albatross/Laysan_Albatross_0100_735.jpg                  1         2                002.Laysan_Albatross  136.0   66.0  171.0   243.0
# 111         112                                 002.Laysan_Albatross/Laysan_Albatross_0021_737.jpg                  0         2                002.Laysan_Albatross  140.0  100.0  237.0   199.0
# 112         113                                 002.Laysan_Albatross/Laysan_Albatross_0029_482.jpg                  1         2                002.Laysan_Albatross   31.0   52.0  377.0   172.0
# 113         114                                 002.Laysan_Albatross/Laysan_Albatross_0059_488.jpg                  0         2                002.Laysan_Albatross   26.0   53.0  331.0   211.0
# 114         115                                 002.Laysan_Albatross/Laysan_Albatross_0018_492.jpg                  1         2                002.Laysan_Albatross  183.0   80.0  237.0   200.0
# 115         116                                 002.Laysan_Albatross/Laysan_Albatross_0083_756.jpg                  1         2                002.Laysan_Albatross  128.0  109.0  221.0   198.0
# 116         117                                002.Laysan_Albatross/Laysan_Albatross_0094_1013.jpg                  1         2                002.Laysan_Albatross  165.0   48.0  166.0   268.0
# 117         118                                 002.Laysan_Albatross/Laysan_Albatross_0103_504.jpg                  0         2                002.Laysan_Albatross  145.0   42.0  182.0   288.0
# 118         119                                 002.Laysan_Albatross/Laysan_Albatross_0079_506.jpg                  0         2                002.Laysan_Albatross   92.0   69.0  366.0   269.0
# 119         120                                002.Laysan_Albatross/Laysan_Albatross_0051_1020.jpg                  1         2                002.Laysan_Albatross   77.0   93.0  163.0   178.0
# 120         121                                  003.Sooty_Albatross/Sooty_Albatross_0038_1065.jpg                  1         3                 003.Sooty_Albatross  196.0   96.0  222.0   147.0
# 121         122                                  003.Sooty_Albatross/Sooty_Albatross_0031_1066.jpg                  1         3                 003.Sooty_Albatross  102.0  128.0  396.0   148.0
# 122         123                                  003.Sooty_Albatross/Sooty_Albatross_0001_1071.jpg                  1         3                 003.Sooty_Albatross  105.0  133.0  168.0   283.0
# 123         124                                  003.Sooty_Albatross/Sooty_Albatross_0016_1075.jpg                  1         3                 003.Sooty_Albatross  169.0   41.0  180.0   249.0
# 124         125                                  003.Sooty_Albatross/Sooty_Albatross_0043_1076.jpg                  1         3                 003.Sooty_Albatross    1.0  134.0  316.0   345.0
# 125         126                                  003.Sooty_Albatross/Sooty_Albatross_0003_1078.jpg                  0         3                 003.Sooty_Albatross   36.0   63.0  448.0   252.0
# 126         127                                  003.Sooty_Albatross/Sooty_Albatross_0077_1080.jpg                  1         3                 003.Sooty_Albatross   92.0  117.0  327.0   121.0
# 127         128                                  003.Sooty_Albatross/Sooty_Albatross_0063_1101.jpg                  1         3                 003.Sooty_Albatross   55.0   49.0  176.0   150.0
# 128         129                                  003.Sooty_Albatross/Sooty_Albatross_0044_1105.jpg                  0         3                 003.Sooty_Albatross  206.0  107.0  140.0   115.0
# 129         130                                  003.Sooty_Albatross/Sooty_Albatross_0071_1116.jpg                  0         3                 003.Sooty_Albatross   98.0   24.0  240.0   313.0
# 130         131                                003.Sooty_Albatross/Sooty_Albatross_0070_796346.jpg                  1         3                 003.Sooty_Albatross  114.0   30.0  205.0   281.0
# 131         132                                  003.Sooty_Albatross/Sooty_Albatross_0030_1122.jpg                  0         3                 003.Sooty_Albatross   75.0    2.0  397.0   330.0
# 132         133                                003.Sooty_Albatross/Sooty_Albatross_0054_796347.jpg                  0         3                 003.Sooty_Albatross   86.0   57.0  130.0   270.0
# 133         134                                  003.Sooty_Albatross/Sooty_Albatross_0033_1128.jpg                  0         3                 003.Sooty_Albatross   49.0   75.0  366.0   157.0
# 134         135                                  003.Sooty_Albatross/Sooty_Albatross_0048_1130.jpg                  0         3                 003.Sooty_Albatross   33.0  118.0  235.0   173.0
# 135         136                                  003.Sooty_Albatross/Sooty_Albatross_0032_1149.jpg                  1         3                 003.Sooty_Albatross  121.0   74.0  149.0   134.0
# 136         137                                  003.Sooty_Albatross/Sooty_Albatross_0034_1154.jpg                  1         3                 003.Sooty_Albatross  134.0   96.0  123.0   289.0
# 137         138                                  003.Sooty_Albatross/Sooty_Albatross_0055_1160.jpg                  1         3                 003.Sooty_Albatross  165.0   34.0  288.0   296.0
# 138         139                                  003.Sooty_Albatross/Sooty_Albatross_0024_1161.jpg                  0         3                 003.Sooty_Albatross   98.0  140.0  181.0   247.0
# 139         140                                  003.Sooty_Albatross/Sooty_Albatross_0045_1162.jpg                  1         3                 003.Sooty_Albatross    6.0    1.0  493.0   497.0
# 140         141                                  003.Sooty_Albatross/Sooty_Albatross_0073_1171.jpg                  1         3                 003.Sooty_Albatross   89.0  168.0  160.0   245.0
# 141         142                                  003.Sooty_Albatross/Sooty_Albatross_0074_1221.jpg                  1         3                 003.Sooty_Albatross    9.0   67.0  312.0   252.0
# 142         143                                003.Sooty_Albatross/Sooty_Albatross_0021_796339.jpg                  1         3                 003.Sooty_Albatross    1.0   14.0  250.0   248.0
# 143         144                                003.Sooty_Albatross/Sooty_Albatross_0005_796342.jpg                  0         3                 003.Sooty_Albatross    1.0   15.0  415.0   302.0
# 144         145                                003.Sooty_Albatross/Sooty_Albatross_0064_796343.jpg                  1         3                 003.Sooty_Albatross  191.0   51.0  233.0   253.0
# 145         146                                  003.Sooty_Albatross/Sooty_Albatross_0042_1210.jpg                  0         3                 003.Sooty_Albatross    0.0   67.0  212.0   163.0
# 146         147                                  003.Sooty_Albatross/Sooty_Albatross_0046_1211.jpg                  0         3                 003.Sooty_Albatross  122.0   35.0  377.0   297.0
# 147         148                                003.Sooty_Albatross/Sooty_Albatross_0017_796349.jpg                  1         3                 003.Sooty_Albatross  105.0   77.0  267.0   159.0
# 148         149                                003.Sooty_Albatross/Sooty_Albatross_0049_796350.jpg                  0         3                 003.Sooty_Albatross   16.0   36.0  190.0   289.0
# 149         150                                003.Sooty_Albatross/Sooty_Albatross_0050_796351.jpg                  0         3                 003.Sooty_Albatross   12.0    9.0  466.0   307.0
# 150         151                                003.Sooty_Albatross/Sooty_Albatross_0075_796352.jpg                  1         3                 003.Sooty_Albatross   14.0   39.0  455.0   167.0
# 151         152                                003.Sooty_Albatross/Sooty_Albatross_0068_796353.jpg                  1         3                 003.Sooty_Albatross  165.0   55.0  128.0   219.0
# 152         153                                003.Sooty_Albatross/Sooty_Albatross_0057_796354.jpg                  1         3                 003.Sooty_Albatross   37.0   35.0  142.0   141.0
# 153         154                                003.Sooty_Albatross/Sooty_Albatross_0010_796355.jpg                  0         3                 003.Sooty_Albatross  113.0   91.0  287.0   153.0
# 154         155                                003.Sooty_Albatross/Sooty_Albatross_0029_796357.jpg                  0         3                 003.Sooty_Albatross   15.0   46.0  410.0   338.0
# 155         156                                003.Sooty_Albatross/Sooty_Albatross_0069_796358.jpg                  0         3                 003.Sooty_Albatross  145.0  104.0  217.0   215.0
# 156         157                                003.Sooty_Albatross/Sooty_Albatross_0020_796359.jpg                  0         3                 003.Sooty_Albatross  136.0    6.0  222.0   340.0
# 157         158                                003.Sooty_Albatross/Sooty_Albatross_0058_796360.jpg                  1         3                 003.Sooty_Albatross   22.0   13.0  325.0   428.0
# 158         159                                003.Sooty_Albatross/Sooty_Albatross_0025_796361.jpg                  1         3                 003.Sooty_Albatross    0.0    0.0  400.0   378.0
# 159         160                                003.Sooty_Albatross/Sooty_Albatross_0041_796364.jpg                  1         3                 003.Sooty_Albatross  139.0   33.0  337.0   319.0
# 160         161                                003.Sooty_Albatross/Sooty_Albatross_0076_796365.jpg                  0         3                 003.Sooty_Albatross  247.0   62.0  217.0   251.0
# 161         162                                003.Sooty_Albatross/Sooty_Albatross_0004_796366.jpg                  0         3                 003.Sooty_Albatross  123.0   46.0  267.0   408.0
# 162         163                                003.Sooty_Albatross/Sooty_Albatross_0065_796367.jpg                  0         3                 003.Sooty_Albatross   55.0   65.0  319.0   364.0
# 163         164                                003.Sooty_Albatross/Sooty_Albatross_0072_796371.jpg                  1         3                 003.Sooty_Albatross    0.0   74.0  443.0   200.0
# 164         165                                003.Sooty_Albatross/Sooty_Albatross_0007_796372.jpg                  0         3                 003.Sooty_Albatross   14.0    7.0  477.0   327.0
# 165         166                                003.Sooty_Albatross/Sooty_Albatross_0014_796373.jpg                  1         3                 003.Sooty_Albatross   22.0   98.0  449.0   192.0
# 166         167                                003.Sooty_Albatross/Sooty_Albatross_0051_796374.jpg                  0         3                 003.Sooty_Albatross   27.0   37.0  283.0   232.0
# 167         168                                003.Sooty_Albatross/Sooty_Albatross_0040_796375.jpg                  1         3                 003.Sooty_Albatross   96.0   58.0  246.0   351.0
# 168         169                                003.Sooty_Albatross/Sooty_Albatross_0067_796376.jpg                  0         3                 003.Sooty_Albatross  177.0   13.0  174.0   333.0
# 169         170                                003.Sooty_Albatross/Sooty_Albatross_0066_796382.jpg                  0         3                 003.Sooty_Albatross  132.0   82.0  268.0   206.0
# 170         171                                003.Sooty_Albatross/Sooty_Albatross_0036_796387.jpg                  0         3                 003.Sooty_Albatross  150.0   44.0  156.0   192.0
# 171         172                                003.Sooty_Albatross/Sooty_Albatross_0079_796389.jpg                  1         3                 003.Sooty_Albatross   37.0   18.0  222.0   290.0
# 172         173                                003.Sooty_Albatross/Sooty_Albatross_0006_796390.jpg                  0         3                 003.Sooty_Albatross  209.0    1.0  145.0   326.0
# 173         174                                003.Sooty_Albatross/Sooty_Albatross_0019_796391.jpg                  1         3                 003.Sooty_Albatross  236.0   36.0  123.0   115.0
# 174         175                                003.Sooty_Albatross/Sooty_Albatross_0002_796395.jpg                  0         3                 003.Sooty_Albatross   95.0   65.0  379.0   185.0
# 175         176                                003.Sooty_Albatross/Sooty_Albatross_0022_796398.jpg                  1         3                 003.Sooty_Albatross   20.0   18.0  314.0   367.0
# 176         177                                003.Sooty_Albatross/Sooty_Albatross_0023_796401.jpg                  1         3                 003.Sooty_Albatross   19.0    9.0  183.0   405.0
# 177         178                                003.Sooty_Albatross/Sooty_Albatross_0013_796402.jpg                  0         3                 003.Sooty_Albatross   77.0   38.0  171.0   158.0
# 178         179                              004.Groove_billed_Ani/Groove_Billed_Ani_0068_1538.jpg                  0         4               004.Groove_billed_Ani  214.0   30.0  151.0   327.0
# 179         180                              004.Groove_billed_Ani/Groove_Billed_Ani_0094_1540.jpg                  0         4               004.Groove_billed_Ani   17.0   87.0  433.0   262.0
# 180         181                              004.Groove_billed_Ani/Groove_Billed_Ani_0033_1494.jpg                  1         4               004.Groove_billed_Ani  140.0   76.0  141.0   297.0
# 181         182                              004.Groove_billed_Ani/Groove_Billed_Ani_0069_1546.jpg                  1         4               004.Groove_billed_Ani   62.0  108.0  308.0   310.0
# 182         183                              004.Groove_billed_Ani/Groove_Billed_Ani_0080_1549.jpg                  0         4               004.Groove_billed_Ani  113.0   88.0  216.0   268.0
# 183         184                              004.Groove_billed_Ani/Groove_Billed_Ani_0071_1559.jpg                  1         4               004.Groove_billed_Ani   61.0   41.0  230.0   414.0
# 184         185                              004.Groove_billed_Ani/Groove_Billed_Ani_0037_1560.jpg                  0         4               004.Groove_billed_Ani  226.0  140.0  163.0   109.0
# 185         186                              004.Groove_billed_Ani/Groove_Billed_Ani_0017_1561.jpg                  0         4               004.Groove_billed_Ani   63.0   90.0  435.0   199.0
# 186         187                              004.Groove_billed_Ani/Groove_Billed_Ani_0105_1562.jpg                  1         4               004.Groove_billed_Ani  115.0   62.0  323.0   286.0
# 187         188                              004.Groove_billed_Ani/Groove_Billed_Ani_0090_1567.jpg                  1         4               004.Groove_billed_Ani   71.0   43.0  320.0   245.0
# 188         189                              004.Groove_billed_Ani/Groove_Billed_Ani_0019_1585.jpg                  1         4               004.Groove_billed_Ani  200.0  149.0  111.0   117.0
# 189         190                              004.Groove_billed_Ani/Groove_Billed_Ani_0031_1588.jpg                  0         4               004.Groove_billed_Ani  166.0  113.0  233.0   152.0
# 190         191                              004.Groove_billed_Ani/Groove_Billed_Ani_0107_1590.jpg                  0         4               004.Groove_billed_Ani  170.0   73.0  145.0   212.0
# 191         192                              004.Groove_billed_Ani/Groove_Billed_Ani_0035_1591.jpg                  0         4               004.Groove_billed_Ani   62.0   28.0  234.0   355.0
# 192         193                              004.Groove_billed_Ani/Groove_Billed_Ani_0109_1592.jpg                  0         4               004.Groove_billed_Ani   86.0  100.0  161.0   329.0
# 193         194                              004.Groove_billed_Ani/Groove_Billed_Ani_0036_1604.jpg                  1         4               004.Groove_billed_Ani   61.0   52.0  377.0   290.0
# 194         195                              004.Groove_billed_Ani/Groove_Billed_Ani_0085_1612.jpg                  1         4               004.Groove_billed_Ani  205.0  140.0  182.0   173.0
# 195         196                              004.Groove_billed_Ani/Groove_Billed_Ani_0018_1613.jpg                  1         4               004.Groove_billed_Ani  228.0   28.0  187.0   281.0
# 196         197                              004.Groove_billed_Ani/Groove_Billed_Ani_0007_1615.jpg                  1         4               004.Groove_billed_Ani  166.0   86.0  207.0   214.0
# 197         198                              004.Groove_billed_Ani/Groove_Billed_Ani_0075_1617.jpg                  0         4               004.Groove_billed_Ani  174.0   29.0  264.0   370.0
# 198         199                              004.Groove_billed_Ani/Groove_Billed_Ani_0029_1620.jpg                  0         4               004.Groove_billed_Ani  102.0  103.0  209.0   342.0
# 199         200                              004.Groove_billed_Ani/Groove_Billed_Ani_0108_1639.jpg                  0         4               004.Groove_billed_Ani  103.0   46.0  174.0   328.0
# 200         201                              004.Groove_billed_Ani/Groove_Billed_Ani_0100_1646.jpg                  0         4               004.Groove_billed_Ani  165.0   86.0  126.0   156.0
# 201         202                              004.Groove_billed_Ani/Groove_Billed_Ani_0051_1650.jpg                  1         4               004.Groove_billed_Ani   92.0   94.0  213.0   295.0
# 202         203                              004.Groove_billed_Ani/Groove_Billed_Ani_0015_1653.jpg                  1         4               004.Groove_billed_Ani  102.0   56.0  117.0   176.0
# 203         204                              004.Groove_billed_Ani/Groove_Billed_Ani_0076_1661.jpg                  1         4               004.Groove_billed_Ani  247.0  135.0  106.0   171.0
# 204         205                              004.Groove_billed_Ani/Groove_Billed_Ani_0046_1663.jpg                  0         4               004.Groove_billed_Ani   68.0  157.0  242.0   220.0
# 205         206                              004.Groove_billed_Ani/Groove_Billed_Ani_0002_1670.jpg                  1         4               004.Groove_billed_Ani   24.0   58.0  432.0   238.0
# 206         207                              004.Groove_billed_Ani/Groove_Billed_Ani_0053_1672.jpg                  0         4               004.Groove_billed_Ani  169.0  105.0  220.0   221.0
# 207         208                              004.Groove_billed_Ani/Groove_Billed_Ani_0088_1678.jpg                  0         4               004.Groove_billed_Ani  131.0  101.0  175.0   230.0
# 208         209                              004.Groove_billed_Ani/Groove_Billed_Ani_0072_1696.jpg                  1         4               004.Groove_billed_Ani  147.0  142.0  148.0   208.0
# 209         210                              004.Groove_billed_Ani/Groove_Billed_Ani_0082_1697.jpg                  0         4               004.Groove_billed_Ani  178.0   28.0  124.0   286.0
# 210         211                              004.Groove_billed_Ani/Groove_Billed_Ani_0101_1700.jpg                  0         4               004.Groove_billed_Ani   65.0   54.0  154.0   374.0
# 211         212                              004.Groove_billed_Ani/Groove_Billed_Ani_0010_1704.jpg                  0         4               004.Groove_billed_Ani  184.0   99.0  117.0   193.0
# 212         213                              004.Groove_billed_Ani/Groove_Billed_Ani_0047_1706.jpg                  1         4               004.Groove_billed_Ani  115.0   59.0  329.0   255.0
# 213         214                              004.Groove_billed_Ani/Groove_Billed_Ani_0040_1715.jpg                  0         4               004.Groove_billed_Ani  120.0  144.0  239.0   257.0
# 214         215                              004.Groove_billed_Ani/Groove_Billed_Ani_0077_1724.jpg                  1         4               004.Groove_billed_Ani   22.0  103.0  233.0   314.0
# 215         216                              004.Groove_billed_Ani/Groove_Billed_Ani_0091_1728.jpg                  1         4               004.Groove_billed_Ani   34.0  138.0  287.0   158.0
# 216         217                              004.Groove_billed_Ani/Groove_Billed_Ani_0074_1730.jpg                  0         4               004.Groove_billed_Ani  143.0   70.0  166.0   255.0
# 217         218                              004.Groove_billed_Ani/Groove_Billed_Ani_0044_1731.jpg                  1         4               004.Groove_billed_Ani  110.0   67.0  389.0   233.0
# 218         219                              004.Groove_billed_Ani/Groove_Billed_Ani_0059_1480.jpg                  0         4               004.Groove_billed_Ani  187.0   60.0  134.0   255.0
# 219         220                              004.Groove_billed_Ani/Groove_Billed_Ani_0023_1485.jpg                  1         4               004.Groove_billed_Ani  110.0   75.0  128.0   256.0
# 220         221                              004.Groove_billed_Ani/Groove_Billed_Ani_0004_1528.jpg                  1         4               004.Groove_billed_Ani  290.0   97.0  145.0   142.0
# 221         222                              004.Groove_billed_Ani/Groove_Billed_Ani_0056_1493.jpg                  1         4               004.Groove_billed_Ani   45.0   43.0  270.0   342.0
# 222         223                              004.Groove_billed_Ani/Groove_Billed_Ani_0005_1750.jpg                  0         4               004.Groove_billed_Ani   58.0   54.0  441.0   320.0
# 223         224                              004.Groove_billed_Ani/Groove_Billed_Ani_0058_1751.jpg                  1         4               004.Groove_billed_Ani  160.0   65.0  156.0   234.0
# 224         225                              004.Groove_billed_Ani/Groove_Billed_Ani_0027_1754.jpg                  1         4               004.Groove_billed_Ani   89.0   34.0  228.0   339.0
# 225         226                              004.Groove_billed_Ani/Groove_Billed_Ani_0014_1755.jpg                  0         4               004.Groove_billed_Ani   94.0   22.0  222.0   470.0
# 226         227                              004.Groove_billed_Ani/Groove_Billed_Ani_0055_1501.jpg                  1         4               004.Groove_billed_Ani  123.0   49.0  306.0   200.0
# 227         228                              004.Groove_billed_Ani/Groove_Billed_Ani_0065_1502.jpg                  1         4               004.Groove_billed_Ani  110.0   52.0  219.0   368.0
# 228         229                              004.Groove_billed_Ani/Groove_Billed_Ani_0060_1505.jpg                  0         4               004.Groove_billed_Ani  122.0   64.0  176.0   338.0
# 229         230                              004.Groove_billed_Ani/Groove_Billed_Ani_0006_1763.jpg                  1         4               004.Groove_billed_Ani  188.0  151.0  197.0   115.0
# 230         231                              004.Groove_billed_Ani/Groove_Billed_Ani_0087_1765.jpg                  0         4               004.Groove_billed_Ani   91.0   53.0  250.0   221.0
# 231         232                              004.Groove_billed_Ani/Groove_Billed_Ani_0061_1510.jpg                  1         4               004.Groove_billed_Ani  116.0   37.0  144.0   453.0
# 232         233                              004.Groove_billed_Ani/Groove_Billed_Ani_0062_1767.jpg                  0         4               004.Groove_billed_Ani  114.0   86.0  302.0   285.0
# 233         234                              004.Groove_billed_Ani/Groove_Billed_Ani_0092_1516.jpg                  0         4               004.Groove_billed_Ani  155.0  118.0  222.0   184.0
# 234         235                              004.Groove_billed_Ani/Groove_Billed_Ani_0032_1776.jpg                  1         4               004.Groove_billed_Ani  156.0   25.0  198.0   349.0
# 235         236                              004.Groove_billed_Ani/Groove_Billed_Ani_0009_1522.jpg                  0         4               004.Groove_billed_Ani  215.0   59.0  111.0   353.0
# 236         237                              004.Groove_billed_Ani/Groove_Billed_Ani_0078_1780.jpg                  0         4               004.Groove_billed_Ani   55.0   46.0  121.0   119.0
# 237         238                              004.Groove_billed_Ani/Groove_Billed_Ani_0012_1784.jpg                  1         4               004.Groove_billed_Ani  183.0   98.0  114.0   217.0
# 238         239                                    005.Crested_Auklet/Crested_Auklet_0006_1813.jpg                  0         5                  005.Crested_Auklet  204.0   60.0  152.0   281.0
# 239         240                                  005.Crested_Auklet/Crested_Auklet_0042_794902.jpg                  0         5                  005.Crested_Auklet   48.0   68.0  167.0   414.0
# 240         241                                  005.Crested_Auklet/Crested_Auklet_0061_794904.jpg                  1         5                  005.Crested_Auklet  101.0   64.0  165.0   404.0
# 241         242                                    005.Crested_Auklet/Crested_Auklet_0018_1817.jpg                  1         5                  005.Crested_Auklet   52.0   51.0  278.0   448.0
# 242         243                                  005.Crested_Auklet/Crested_Auklet_0010_794907.jpg                  1         5                  005.Crested_Auklet   22.0   45.0  225.0   373.0
# 243         244                                  005.Crested_Auklet/Crested_Auklet_0041_794910.jpg                  0         5                  005.Crested_Auklet    1.0   14.0  295.0   224.0
# 244         245                                    005.Crested_Auklet/Crested_Auklet_0029_1824.jpg                  1         5                  005.Crested_Auklet   25.0   39.0  247.0   460.0
# 245         246                                    005.Crested_Auklet/Crested_Auklet_0044_1825.jpg                  0         5                  005.Crested_Auklet  124.0  116.0  235.0   245.0
# 246         247                                  005.Crested_Auklet/Crested_Auklet_0013_794914.jpg                  1         5                  005.Crested_Auklet   39.0   59.0  175.0   212.0
# ...
# 11706     11707                                        199.Winter_Wren/Winter_Wren_0141_190152.jpg                  0       199                     199.Winter_Wren  141.0  124.0  286.0   250.0
# 11707     11708                                        199.Winter_Wren/Winter_Wren_0051_189990.jpg                  1       199                     199.Winter_Wren  235.0  103.0  152.0   175.0
# 11708     11709                                        199.Winter_Wren/Winter_Wren_0004_189670.jpg                  0       199                     199.Winter_Wren  243.0   82.0  240.0   219.0
# 11709     11710                                        199.Winter_Wren/Winter_Wren_0065_189675.jpg                  1       199                     199.Winter_Wren  139.0   70.0  215.0   167.0
# 11710     11711                                        199.Winter_Wren/Winter_Wren_0048_189683.jpg                  0       199                     199.Winter_Wren  110.0  107.0  316.0   223.0
# 11711     11712                                        199.Winter_Wren/Winter_Wren_0093_189686.jpg                  0       199                     199.Winter_Wren  138.0   57.0  331.0   279.0
# 11712     11713                                        199.Winter_Wren/Winter_Wren_0071_189689.jpg                  0       199                     199.Winter_Wren  258.0   64.0  182.0   203.0
# 11713     11714                                        199.Winter_Wren/Winter_Wren_0086_189692.jpg                  0       199                     199.Winter_Wren   63.0   40.0  361.0   274.0
# 11714     11715                                        199.Winter_Wren/Winter_Wren_0005_189750.jpg                  1       199                     199.Winter_Wren   52.0   80.0  242.0   222.0
# 11715     11716                                        199.Winter_Wren/Winter_Wren_0030_190311.jpg                  1       199                     199.Winter_Wren  122.0   31.0  357.0   280.0
# 11716     11717                                        199.Winter_Wren/Winter_Wren_0026_189816.jpg                  1       199                     199.Winter_Wren   36.0   30.0  278.0   300.0
# 11717     11718                                        199.Winter_Wren/Winter_Wren_0126_190342.jpg                  1       199                     199.Winter_Wren  118.0  131.0  177.0   148.0
# 11718     11719                                        199.Winter_Wren/Winter_Wren_0116_189834.jpg                  1       199                     199.Winter_Wren   70.0  120.0  168.0   150.0
# 11719     11720                                        199.Winter_Wren/Winter_Wren_0003_189838.jpg                  0       199                     199.Winter_Wren   76.0  108.0  199.0   198.0
# 11720     11721                                        199.Winter_Wren/Winter_Wren_0129_189843.jpg                  1       199                     199.Winter_Wren  110.0  107.0  277.0   192.0
# 11721     11722                                        199.Winter_Wren/Winter_Wren_0109_189850.jpg                  1       199                     199.Winter_Wren  116.0  123.0  213.0   245.0
# 11722     11723                                        199.Winter_Wren/Winter_Wren_0132_189861.jpg                  0       199                     199.Winter_Wren  127.0   29.0  165.0   264.0
# 11723     11724                                        199.Winter_Wren/Winter_Wren_0029_190376.jpg                  1       199                     199.Winter_Wren   46.0   61.0  240.0   286.0
# 11724     11725                                        199.Winter_Wren/Winter_Wren_0142_190379.jpg                  0       199                     199.Winter_Wren  190.0  104.0  143.0   128.0
# 11725     11726                                        199.Winter_Wren/Winter_Wren_0077_190366.jpg                  1       199                     199.Winter_Wren  223.0   92.0  154.0   178.0
# 11726     11727                                        199.Winter_Wren/Winter_Wren_0047_190390.jpg                  0       199                     199.Winter_Wren  109.0  139.0  250.0   229.0
# 11727     11728                                        199.Winter_Wren/Winter_Wren_0118_189805.jpg                  1       199                     199.Winter_Wren   99.0  126.0  307.0   291.0
# 11728     11729                        200.Common_Yellowthroat/Common_Yellowthroat_0020_190720.jpg                  0       200             200.Common_Yellowthroat  129.0   58.0  244.0   399.0
# 11729     11730                        200.Common_Yellowthroat/Common_Yellowthroat_0016_190986.jpg                  0       200             200.Common_Yellowthroat  104.0  170.0  143.0   228.0
# 11730     11731                        200.Common_Yellowthroat/Common_Yellowthroat_0077_190990.jpg                  1       200             200.Common_Yellowthroat   49.0   80.0  378.0   269.0
# 11731     11732                        200.Common_Yellowthroat/Common_Yellowthroat_0104_190489.jpg                  1       200             200.Common_Yellowthroat   75.0   57.0  287.0   371.0
# 11732     11733                        200.Common_Yellowthroat/Common_Yellowthroat_0114_190501.jpg                  0       200             200.Common_Yellowthroat  132.0  153.0  171.0   188.0
# 11733     11734                        200.Common_Yellowthroat/Common_Yellowthroat_0090_190503.jpg                  1       200             200.Common_Yellowthroat  206.0   40.0  139.0   209.0
# 11734     11735                        200.Common_Yellowthroat/Common_Yellowthroat_0039_190513.jpg                  0       200             200.Common_Yellowthroat  113.0  101.0  375.0   232.0
# 11735     11736                        200.Common_Yellowthroat/Common_Yellowthroat_0003_190521.jpg                  1       200             200.Common_Yellowthroat  155.0  101.0  321.0   242.0
# 11736     11737                        200.Common_Yellowthroat/Common_Yellowthroat_0019_190524.jpg                  0       200             200.Common_Yellowthroat  190.0  123.0  166.0   221.0
# 11737     11738                        200.Common_Yellowthroat/Common_Yellowthroat_0081_190525.jpg                  1       200             200.Common_Yellowthroat  221.0   89.0  233.0   255.0
# 11738     11739                        200.Common_Yellowthroat/Common_Yellowthroat_0028_190527.jpg                  1       200             200.Common_Yellowthroat  125.0   71.0  238.0   373.0
# 11739     11740                        200.Common_Yellowthroat/Common_Yellowthroat_0099_190531.jpg                  0       200             200.Common_Yellowthroat  242.0  128.0  187.0   111.0
# 11740     11741                        200.Common_Yellowthroat/Common_Yellowthroat_0125_190902.jpg                  0       200             200.Common_Yellowthroat   59.0  104.0  398.0   243.0
# 11741     11742                        200.Common_Yellowthroat/Common_Yellowthroat_0050_190535.jpg                  0       200             200.Common_Yellowthroat  139.0   73.0  337.0   282.0
# 11742     11743                        200.Common_Yellowthroat/Common_Yellowthroat_0106_190989.jpg                  1       200             200.Common_Yellowthroat  131.0   82.0  176.0   198.0
# 11743     11744                        200.Common_Yellowthroat/Common_Yellowthroat_0025_190547.jpg                  0       200             200.Common_Yellowthroat  143.0  107.0  184.0   164.0
# 11744     11745                        200.Common_Yellowthroat/Common_Yellowthroat_0118_190805.jpg                  0       200             200.Common_Yellowthroat   70.0   86.0  209.0   186.0
# 11745     11746                        200.Common_Yellowthroat/Common_Yellowthroat_0015_190556.jpg                  1       200             200.Common_Yellowthroat  190.0   74.0  173.0   184.0
# 11746     11747                        200.Common_Yellowthroat/Common_Yellowthroat_0045_190563.jpg                  0       200             200.Common_Yellowthroat   77.0   66.0  331.0   265.0
# 11747     11748                        200.Common_Yellowthroat/Common_Yellowthroat_0035_190567.jpg                  1       200             200.Common_Yellowthroat   62.0   94.0  334.0   259.0
# 11748     11749                        200.Common_Yellowthroat/Common_Yellowthroat_0111_190569.jpg                  0       200             200.Common_Yellowthroat   90.0    6.0  407.0   267.0
# 11749     11750                        200.Common_Yellowthroat/Common_Yellowthroat_0122_190570.jpg                  1       200             200.Common_Yellowthroat   22.0  190.0  205.0   248.0
# 11750     11751                        200.Common_Yellowthroat/Common_Yellowthroat_0112_190571.jpg                  0       200             200.Common_Yellowthroat   95.0   51.0  198.0   285.0
# 11751     11752                        200.Common_Yellowthroat/Common_Yellowthroat_0010_190572.jpg                  1       200             200.Common_Yellowthroat  142.0   57.0  215.0   221.0
# 11752     11753                        200.Common_Yellowthroat/Common_Yellowthroat_0092_190573.jpg                  1       200             200.Common_Yellowthroat   88.0  123.0  264.0   248.0
# 11753     11754                        200.Common_Yellowthroat/Common_Yellowthroat_0006_190576.jpg                  1       200             200.Common_Yellowthroat  187.0  113.0  201.0   181.0
# 11754     11755                        200.Common_Yellowthroat/Common_Yellowthroat_0009_190578.jpg                  1       200             200.Common_Yellowthroat    8.0   51.0  380.0   227.0
# 11755     11756                        200.Common_Yellowthroat/Common_Yellowthroat_0031_190582.jpg                  0       200             200.Common_Yellowthroat  276.0   66.0  124.0   197.0
# 11756     11757                        200.Common_Yellowthroat/Common_Yellowthroat_0059_190584.jpg                  0       200             200.Common_Yellowthroat  227.0   54.0  115.0   201.0
# 11757     11758                        200.Common_Yellowthroat/Common_Yellowthroat_0032_190592.jpg                  1       200             200.Common_Yellowthroat  146.0   84.0  288.0   213.0
# 11758     11759                        200.Common_Yellowthroat/Common_Yellowthroat_0088_190594.jpg                  1       200             200.Common_Yellowthroat   36.0   40.0  426.0   334.0
# 11759     11760                        200.Common_Yellowthroat/Common_Yellowthroat_0121_190597.jpg                  1       200             200.Common_Yellowthroat   39.0   99.0  313.0   206.0
# 11760     11761                        200.Common_Yellowthroat/Common_Yellowthroat_0046_190446.jpg                  0       200             200.Common_Yellowthroat  127.0   51.0  277.0   257.0
# 11761     11762                        200.Common_Yellowthroat/Common_Yellowthroat_0004_190606.jpg                  1       200             200.Common_Yellowthroat  149.0  159.0  218.0   114.0
# 11762     11763                        200.Common_Yellowthroat/Common_Yellowthroat_0093_190609.jpg                  1       200             200.Common_Yellowthroat   51.0  111.0  324.0   221.0
# 11763     11764                        200.Common_Yellowthroat/Common_Yellowthroat_0027_190869.jpg                  0       200             200.Common_Yellowthroat  203.0  138.0  198.0   154.0
# 11764     11765                        200.Common_Yellowthroat/Common_Yellowthroat_0126_190407.jpg                  1       200             200.Common_Yellowthroat   49.0   27.0  318.0   241.0
# 11765     11766                        200.Common_Yellowthroat/Common_Yellowthroat_0086_190639.jpg                  0       200             200.Common_Yellowthroat   40.0   70.0  242.0   198.0
# 11766     11767                        200.Common_Yellowthroat/Common_Yellowthroat_0075_190900.jpg                  1       200             200.Common_Yellowthroat  177.0   18.0  201.0   263.0
# 11767     11768                        200.Common_Yellowthroat/Common_Yellowthroat_0066_190646.jpg                  0       200             200.Common_Yellowthroat  192.0   66.0  220.0   192.0
# 11768     11769                        200.Common_Yellowthroat/Common_Yellowthroat_0018_190904.jpg                  0       200             200.Common_Yellowthroat  100.0  115.0  218.0   131.0
# 11769     11770                        200.Common_Yellowthroat/Common_Yellowthroat_0054_190398.jpg                  1       200             200.Common_Yellowthroat   71.0   37.0  171.0   212.0
# 11770     11771                        200.Common_Yellowthroat/Common_Yellowthroat_0021_190655.jpg                  0       200             200.Common_Yellowthroat  168.0  107.0  245.0   147.0
# 11771     11772                        200.Common_Yellowthroat/Common_Yellowthroat_0069_190400.jpg                  1       200             200.Common_Yellowthroat  272.0   72.0  155.0   388.0
# 11772     11773                        200.Common_Yellowthroat/Common_Yellowthroat_0011_190401.jpg                  0       200             200.Common_Yellowthroat   59.0   48.0  188.0   372.0
# 11773     11774                        200.Common_Yellowthroat/Common_Yellowthroat_0072_190402.jpg                  1       200             200.Common_Yellowthroat   95.0   17.0  315.0   350.0
# 11774     11775                        200.Common_Yellowthroat/Common_Yellowthroat_0029_190403.jpg                  0       200             200.Common_Yellowthroat   59.0   85.0  285.0   160.0
# 11775     11776                        200.Common_Yellowthroat/Common_Yellowthroat_0080_190663.jpg                  1       200             200.Common_Yellowthroat   11.0   89.0  383.0   171.0
# 11776     11777                        200.Common_Yellowthroat/Common_Yellowthroat_0071_190665.jpg                  0       200             200.Common_Yellowthroat  121.0  168.0  284.0   148.0
# 11777     11778                        200.Common_Yellowthroat/Common_Yellowthroat_0087_190414.jpg                  1       200             200.Common_Yellowthroat   35.0  115.0  290.0   197.0
# 11778     11779                        200.Common_Yellowthroat/Common_Yellowthroat_0070_190678.jpg                  0       200             200.Common_Yellowthroat  211.0   79.0  129.0   279.0
# 11779     11780                        200.Common_Yellowthroat/Common_Yellowthroat_0040_190427.jpg                  0       200             200.Common_Yellowthroat   44.0  114.0  269.0   230.0
# 11780     11781                        200.Common_Yellowthroat/Common_Yellowthroat_0098_190430.jpg                  1       200             200.Common_Yellowthroat   41.0   33.0  379.0   426.0
# 11781     11782                        200.Common_Yellowthroat/Common_Yellowthroat_0094_190690.jpg                  1       200             200.Common_Yellowthroat  140.0  125.0  144.0   172.0
# 11782     11783                        200.Common_Yellowthroat/Common_Yellowthroat_0063_190440.jpg                  0       200             200.Common_Yellowthroat   96.0   71.0  243.0   216.0
# 11783     11784                        200.Common_Yellowthroat/Common_Yellowthroat_0037_190698.jpg                  1       200             200.Common_Yellowthroat   89.0   95.0  354.0   250.0
# 11784     11785                        200.Common_Yellowthroat/Common_Yellowthroat_0058_190958.jpg                  0       200             200.Common_Yellowthroat  157.0   62.0  184.0   219.0
# 11785     11786                        200.Common_Yellowthroat/Common_Yellowthroat_0008_190703.jpg                  0       200             200.Common_Yellowthroat  190.0  102.0  198.0   202.0
# 11786     11787                        200.Common_Yellowthroat/Common_Yellowthroat_0049_190708.jpg                  1       200             200.Common_Yellowthroat    3.0   20.0  408.0   307.0
# 11787     11788                        200.Common_Yellowthroat/Common_Yellowthroat_0055_190967.jpg                  0       200             200.Common_Yellowthroat   20.0  113.0  177.0   263.0
# 11788

# %%
print(len(parts))
print(len(part_locs))
print(len(part_click_locs))
# Out:
# 15
# 176820
# 794258

# %%
part_locs = pd.merge(part_locs,parts, on='part_id')
print(part_locs)
part_click_locs = pd.merge(part_click_locs,parts, on='part_id')
print(part_click_locs)
# Out:
#         image_id  part_id      x      y  visible   part_name
# 0              1        1    0.0    0.0        0        back
# 1              1        2  312.0  182.0        1        beak
# 2              1        3    0.0    0.0        0       belly
# 3              1        4    0.0    0.0        0      breast
# 4              1        5  186.0   45.0        1       crown
# ...          ...      ...    ...    ...      ...         ...
# 176815     11788       11  136.0  133.0        1   right eye
# 176816     11788       12  102.0  316.0        1   right leg
# 176817     11788       13   94.0  224.0        1  right wing
# 176818     11788       14   36.0  329.0        1        tail
# 176819     11788       15  166.0  161.0        1      throat
#
# [176820 rows x 6 columns]
#         image_id  part_id      x      y  visible   time part_name
# 0              1        1    0.0    0.0        0  2.329      back
# 1              1        1    0.0    0.0        0  2.294      back
# 2              1        1    0.0    0.0        0  2.359      back
# 3              1        1    0.0    0.0        0  5.813      back
# 4              1        1    0.0    0.0        0  6.303      back
# ...          ...      ...    ...    ...      ...    ...       ...
# 794253     11788       15  167.0  161.0        1  2.644    throat
# 794254     11788       15  168.0  155.0        1  1.713    throat
# 794255     11788       15  157.0  164.0        1  1.744    throat
# 794256     11788       15  166.0  154.0        1  0.856    throat
# 794257     11788       15  162.0  167.0        1  1.750    throat
#
# [794258 rows x 7 columns]

# %%
print(len(attributes))
print(len(image_attribute_labels))
print(len(certainties))
# Out:
# 312
# 3677856
# 4

# %%
image_attribute_labels = pd.merge(image_attribute_labels,attributes, on='attribute_id')
image_attribute_labels = pd.merge(image_attribute_labels,certainties, on='certainty_id')
print(image_attribute_labels)
# Out:
#          image_id  attribute_id  is_present  certainty_id    time  \
# 0               1             1           0             3  27.708
# 1               1             2           0             3  27.708
# 2               1             3           0             3  27.708
# 3               1             4           0             3  27.708
# 4               1             5           1             3  27.708
# ...           ...           ...         ...           ...     ...
# 3677851     11788           308           1             4   4.989
# 3677852     11788           309           0             4   8.309
# 3677853     11788           310           0             4   8.309
# 3677854     11788           311           0             4   8.309
# 3677855     11788           312           1             4   8.309
#
#                               attribute_name certainty_name
# 0        has_bill_shape::curved_(up_or_down)       probably
# 1                     has_bill_shape::dagger       probably
# 2                     has_bill_shape::hooked       probably
# 3                     has_bill_shape::needle       probably
# 4             has_bill_shape::hooked_seabird       probably
# ...                                      ...            ...
# 3677851                has_crown_color::buff     definitely
# 3677852              has_wing_pattern::solid     definitely
# 3677853            has_wing_pattern::spotted     definitely
# 3677854            has_wing_pattern::striped     definitely
# 3677855      has_wing_pattern::multi-colored     definitely
#
# [3677856 rows x 7 columns]

# %% [markdown]
# ##**Description of cleaned dataframes:**
#
# 1.  image_data :
# *   contains data from images, train_test_split, classes, image_class_labels, bounding_boxes.
# *   columns: 'image_id', 'image_name', 'is_training_image', 'class_id', 'class_name', 'x', 'y', 'width', 'height'
# *   dimensions: 11788 rows x 9 columns
#
# 2.  part_locs :
# *   contains data from part_locs, parts.
# *   columns: 'image_id', 'part_id', 'x', 'y', 'visible', 'part_name'
# *   dimensions: 176820 rows x 6 columns
#
# 3.  part_click_locs :
# *   contains data from part_click_locs, parts.
# *   columns: image_id', 'part_id', 'x', 'y', 'visible', 'time', 'part_name'
# *   dimensions: 794258 rows x 7 columns
#
# 4.  image_attribute_labels :
# *   contains data from image_attribute_labels, attributes, certainties.
# *   columns: 'image_id', 'attribute_id', 'is_present', 'certainty_id', 'time',
#       'attribute_name', 'certainty_name'
# *   dimensions: 3677856 rows x 7 columns
#
# 5.  class_attribute_labels_continuous :
# *   rows: each row represents a bird class (same order as classes.txt)
# *   columns: each column represents an attribute (same order as attributes.txt)
# *   dimensions: 200 rows x 312 columns

# %%
##split training and testing image data
training_image_data = image_data[image_data['is_training_image']==1]
testing_image_data = image_data[image_data['is_training_image']==0]

##shuffle training data
training_image_data = training_image_data.sample(frac=1)

##empty lists for training and testing images
training_images = []
testing_images = []

##filling in lists for testing and training images
for i in (training_image_data['image_name'].values):
    training_images.append(image.load_img('CUB_200_2011/images/{}'.format(i), target_size=(224, 224)))

for i in (testing_image_data['image_name'].values):
    testing_images.append(image.load_img('CUB_200_2011/images/{}'.format(i), target_size=(224, 224)))

##class labels - encoded
training_class_label = np.array(training_image_data['class_id'].values)
testing_class_label = np.array(testing_image_data['class_id'].values)

# %%
# Data preprocessing function for xception
def preprocess(image, label):
  final_image = keras.applications.xception.preprocess_input(image)
  return final_image, label

##preprocessing testing and training data using function
preprocessed_training_images = preprocess(np.array(training_images), training_class_label)
preprocessed_testing_images = preprocess(np.array(testing_images), testing_class_label)

# %%
# Split the training data into training and validation sets, the validation set is 30% of the training data
x_train, x_val, y_train, y_val = train_test_split(preprocessed_training_images[0], 
                                                  preprocessed_training_images[1], 
                                                  test_size=0.3, 
                                                  random_state=42)

# %%
# One hot encode the data so the outputs are discrete and they work with the keras metrics function
y_train_encoded = to_categorical(y_train, num_classes=201)
y_val_encoded = to_categorical(y_val, num_classes=201)
y_test_encoded = to_categorical(preprocessed_testing_images[1], num_classes=201)

# %%
# The code for data augmentation if implementation is desired. Our best performing model (this one) does not
# augment the data
from tensorflow.keras.preprocessing.image import ImageDataGenerator

gen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.2,
    zoom_range=0.3,
    fill_mode='nearest',
    horizontal_flip=True,
    vertical_flip=False
)

# # Generate augmented data
# augmented_train_generator = gen.flow(x_train, y_train_encoded, batch_size=32)

# %%
# Fine-tuning xception model (globalaveragepooling turns it in to a vector)
base_model = keras.applications.xception.Xception(weights="imagenet", include_top=False)
avg = keras.layers.GlobalAveragePooling2D()(base_model.output)

# Add output layer to model
output = keras.layers.Dense(201, activation="softmax")(avg)
model = keras.Model(inputs=base_model.input, outputs=output)

# %%
# Code for the model built using Convolutional layers if testing with various non-pretrained models is desired
# Uncomment the below and comment the above cell if wanting to change model bases.

# # Load pre-trained Xception model without the top layers
# base_model = keras.applications.Xception(weights="imagenet", include_top=False)

# # Freeze the base model layers
# base_model.trainable = False

# # Add your custom layers on top of the base model
# model = keras.Sequential()
# model.add(base_model)
# model.add(layers.Conv2D(512, 3, activation="relu", padding="same"))  # Add padding to preserve spatial dimensions
# model.add(layers.Conv2D(512, 3, activation="relu", padding="same"))
# model.add(layers.MaxPooling2D(3))
# model.add(layers.GlobalAveragePooling2D())
# model.add(layers.Dense(201, activation="softmax"))

# %%
# Code to add regularization to the model if desired.
'''
  silva2019kerasregularization,
  title={How to Add Regularization to Keras Pre-trained Models the Right Way},
  author={Silva, Thalles Santos},
  journal={https://sthalles.github.io},
  year={2019}
  url={https://sthalles.github.io/keras-regularizer/}
'''
def add_regularization(model, regularizer=tf.keras.regularizers.l2(0.00001)):

    if not isinstance(regularizer, tf.keras.regularizers.Regularizer):
      print("Regularizer must be a subclass of tf.keras.regularizers.Regularizer")
      return model

    for layer in model.layers:
        for attr in ['kernel_regularizer']:
            if hasattr(layer, attr):
              setattr(layer, attr, regularizer)

    # When we change the layers attributes, the change only happens in the model config file
    model_json = model.to_json()

    # Save the weights before reloading the model.
    tmp_weights_path = os.path.join(tempfile.gettempdir(), 'tmp.weights.h5')
    model.save_weights(tmp_weights_path)

    # load the model from the config
    model = tf.keras.models.model_from_json(model_json)
    
    # Reload the model weights
    model.load_weights(tmp_weights_path)#, by_name=True)
    return model

# %%
# Uncomment and adjust the regularization parameter as needed if desired.
# model = add_regularization(model, regularizer=tf.keras.regularizers.l2(0.00001))

# %%
dataset_size = len(training_images)

# Define a learning rate scheduler 
# Tune the hyperparameters to document how they affect model performance
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.02,
    decay_steps=10000,
    decay_rate=0.9)

# Early stopping to prevent overfitting
earlystopping = callbacks.EarlyStopping(monitor="val_loss",
                                        mode="min",
                                        patience=3,
                                        restore_best_weights=True)


# Training with existing layers fixed to make sure the added ouput layer works
for layer in base_model.layers:
    layer.trainable = False

# set up the optimizer and compile the model using categorical crossentropy loss
optimizer = keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9)
model.compile(loss="categorical_crossentropy", 
              optimizer=optimizer, metrics=['accuracy', 
              keras.metrics.Precision(), 
              keras.metrics.Recall(), 
              keras.metrics.F1Score()])

#fit the model to the training and validation data to begin network training
history = model.fit(x_train, y_train_encoded, 
                    epochs=5, 
                    batch_size=32, 
                    validation_data=(x_val, y_val_encoded), callbacks=[earlystopping])

print()
# Out:
# Epoch 1/5
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 286s 2s/step - accuracy: 0.0861 - f1_score: 0.0712 - loss: 4.7269 - precision: 0.4494 - recall: 0.0041 - val_accuracy: 0.2668 - val_f1_score: 0.2338 - val_loss: 3.0994 - val_precision: 0.8354 - val_recall: 0.0367
# Epoch 2/5
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 290s 2s/step - accuracy: 0.4141 - f1_score: 0.3743 - loss: 2.5504 - precision: 0.8014 - recall: 0.0940 - val_accuracy: 0.4069 - val_f1_score: 0.3740 - val_loss: 2.4509 - val_precision: 0.8398 - val_recall: 0.1195
# Epoch 3/5
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 288s 2s/step - accuracy: 0.5773 - f1_score: 0.5260 - loss: 1.8093 - precision: 0.9144 - recall: 0.2230 - val_accuracy: 0.4419 - val_f1_score: 0.4170 - val_loss: 2.2307 - val_precision: 0.8320 - val_recall: 0.1707
# Epoch 4/5
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.6691 - f1_score: 0.6226 - loss: 1.4419 - precision: 0.9380 - recall: 0.3256 - val_accuracy: 0.4397 - val_f1_score: 0.4238 - val_loss: 2.1444 - val_precision: 0.7630 - val_recall: 0.2040
# Epoch 5/5
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 211s 2s/step - accuracy: 0.7174 - f1_score: 0.6711 - loss: 1.2326 - precision: 0.9435 - recall: 0.3998 - val_accuracy: 0.4797 - val_f1_score: 0.4619 - val_loss: 2.0274 - val_precision: 0.8039 - val_recall: 0.2507

# %%
# Train the model again with the base layers unfrozen
for layer in base_model.layers:
  layer.trainable = True

optimizer = keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9)
model.compile(loss="categorical_crossentropy", 
              optimizer=optimizer,metrics=['accuracy', 
              keras.metrics.Precision(), 
              keras.metrics.Recall(), 
              keras.metrics.F1Score()])
history = model.fit(x_train, y_train_encoded, 
                    epochs=5, 
                    batch_size=32, 
                    validation_data=(x_val, y_val_encoded), callbacks=[earlystopping])
# Out:
# Epoch 1/5
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 757s 6s/step - accuracy: 0.5980 - f1_score: 0.5501 - loss: 1.7261 - precision_1: 0.9112 - recall_1: 0.2917 - val_accuracy: 0.4091 - val_f1_score: 0.4008 - val_loss: 2.4883 - val_precision_1: 0.5399 - val_recall_1: 0.3085
# Epoch 2/5
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1112s 8s/step - accuracy: 0.8887 - f1_score: 0.8401 - loss: 0.4879 - precision_1: 0.9541 - recall_1: 0.7752 - val_accuracy: 0.5970 - val_f1_score: 0.5891 - val_loss: 1.5058 - val_precision_1: 0.7785 - val_recall_1: 0.4747
# Epoch 3/5
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1059s 8s/step - accuracy: 0.9722 - f1_score: 0.9245 - loss: 0.1641 - precision_1: 0.9814 - recall_1: 0.9472 - val_accuracy: 0.6681 - val_f1_score: 0.6610 - val_loss: 1.2511 - val_precision_1: 0.8016 - val_recall_1: 0.5570
# Epoch 4/5
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1059s 8s/step - accuracy: 0.9904 - f1_score: 0.9494 - loss: 0.0605 - precision_1: 0.9908 - recall_1: 0.9887 - val_accuracy: 0.6782 - val_f1_score: 0.6689 - val_loss: 1.2303 - val_precision_1: 0.7935 - val_recall_1: 0.5981
# Epoch 5/5
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1043s 8s/step - accuracy: 0.9981 - f1_score: 0.9527 - loss: 0.0298 - precision_1: 0.9981 - recall_1: 0.9978 - val_accuracy: 0.6854 - val_f1_score: 0.6749 - val_loss: 1.2104 - val_precision_1: 0.8001 - val_recall_1: 0.6031

# %%
# Evaluate the model on the testing data to obtain the model performance metrics
results = model.evaluate(preprocessed_testing_images[0], y_test_encoded)
# Out:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 281s 2s/step - accuracy: 0.6948 - f1_score: 0.3619 - loss: 1.1103 - precision_1: 0.7977 - recall_1: 0.6185
